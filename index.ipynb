# %% [markdown]
# ### Bonjour
# ## Bonjour

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ---
# #### PROGRAMME 7 :Write a Ptyhon program to convert Celsius to Fahrenheit
# ---
# ## By: Kakos2000
# ## Date: 23/02/2026
# ## Module: Programmation python de base
#
# # Objectifs:
# Prendre en main la programmation Python pour Dev de IA

# %%
while True:
    try:
        cels = float(input("entrer la température en Celsius: "))
   
        fah = (cels*9/5) + 32
        print(f"\n la température associée en Fahrenheit est: {fah}")
        break
    except ValueError:
        print("la valeur entrée de la température en Celsius est erronée, Veuillez entrer une valeur correcte.")
        continue
            
#Comment tester si une valeur est un float et comment faire que le except reste dans la 

print("Fin du programme est le suivant")

# %%
try:
    print("Ce programme vous permet de faire les différentes opérations")
    operateur = input(""" print("choisir l'opération que vous souhaitez effectuer:\n)
                    \n\t ✌ + : Addition
                    \n\t ✌ - : Soustraction
                    \n\t ✌ * : Multiplication
                    \n\t ✌ % : Modulo
                    """)

    if operateur == "+":
        somme=0
        nombre = 1
        print(f"l\'opération choisie est l`'addition: {operateur}") 
        valeur = input("entrer le Premier nombre à additionner : ").strip().lower()
        while (valeur != "="):
            somme = somme + int(valeur)
            print(f"la somme des nombres communiqués jusqu\'à présent est {somme} ")
            nombre= nombre +1
            valeur = input(f"entrer le {nombre}e à additionner : ").strip().lower()
            if valeur == "=":
                nombre= nombre - 1
                print(f"fin de l\'opération, la somme des {nombre} nombres entrés est: {somme}" )
                break
        
    elif operateur == "*":
        produit=1
        nombre = 1
        print(f"l\'opération choisie est la Multiplication: {operateur}") 
        valeur = input("entrer le Premier nombre à multiplier : ").strip().lower()
        while (valeur != "="):
            produit = produit * int(valeur)
            print(f"Le produit des nombres communiqués jusqu\'à présent est : {produit} ")
            nombre= nombre +1
            valeur = input(f"entrer le {nombre}e à multiplier : ").strip().lower()
            if valeur == "=":
                nombre= nombre - 1
                print(f"fin de l\'opération, le produit des {nombre} nombres entrés est : {produit}" )
                break
    else:
        print(f"l\'opérateur \'{operateur}\' indiqué n'est pas valide, fin du programme ...")
        

except ValueError:
    print("la valeur entrée est erronée ... Fin du programme")

# %%
import random

print(f"Random number: {random.randint(1,10)}")
